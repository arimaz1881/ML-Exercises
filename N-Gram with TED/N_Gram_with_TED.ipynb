# %%
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt

# %%
#@title Importing dataset

data = pd.read_csv("ted_main.csv")
data = data[['description', 'title']]
(data)
# Out:
#                                             description  \
# 0     Sir Ken Robinson makes an entertaining and pro...
# 1     With the same humor and humanity he exuded in ...
# 2     New York Times columnist David Pogue takes aim...
# 3     In an emotionally charged talk, MacArthur-winn...
# 4     You've never seen data presented like this. Wi...
# ...                                                 ...
# 2545  Between 2008 and 2016, the United States depor...
# 2546  How can you study Mars without a spaceship? He...
# 2547  Science fiction visions of the future show us ...
# 2548  In an unmissable talk about race and politics ...
# 2549  With more than half of the world population li...
#
#                                                   title
# 0                           Do schools kill creativity?
# 1                           Averting the climate crisis
# 2                                      Simplicity sells
# 3                                   Greening the ghetto
# 4                       The best stats you've ever seen
# ...                                                 ...
# 2545  What we're missing in the debate about immigra...
# 2546                    The most Martian place on Earth
# 2547  What intelligent machines can learn from a sch...
# 2548       A black man goes undercover in the alt-right
# 2549  How a video game might help us build better ci...
#
# [2550 rows x 2 columns]

# %%
data['description'][0]
# Out:
# 'Sir Ken Robinson makes an entertaining and profoundly moving case for creating an education system that nurtures (rather than undermines) creativity.'

# %%
lines = data.apply(lambda row: row['title'] + " ; " + row['description'], axis=1).tolist()

lines[0]
# Out:
# 'Do schools kill creativity? ; Sir Ken Robinson makes an entertaining and profoundly moving case for creating an education system that nurtures (rather than undermines) creativity.'

# %%
#@title Tokenization
"""
Turn lines to lowercase, then tokenize,
then concat tokens together,
into space-separated string
"""
from nltk.tokenize import WordPunctTokenizer

def tokenize(raw_lines):
  tokenizer = WordPunctTokenizer()
  tokens = [tokenizer.tokenize(line.lower()) for line in raw_lines]
  return tokens

# %%
#checking format of data
t=tokenize(lines[:5])
for line in t:
  print(line)
# Out:
# ['do', 'schools', 'kill', 'creativity', '?', ';', 'sir', 'ken', 'robinson', 'makes', 'an', 'entertaining', 'and', 'profoundly', 'moving', 'case', 'for', 'creating', 'an', 'education', 'system', 'that', 'nurtures', '(', 'rather', 'than', 'undermines', ')', 'creativity', '.']
# ['averting', 'the', 'climate', 'crisis', ';', 'with', 'the', 'same', 'humor', 'and', 'humanity', 'he', 'exuded', 'in', '"', 'an', 'inconvenient', 'truth', ',"', 'al', 'gore', 'spells', 'out', '15', 'ways', 'that', 'individuals', 'can', 'address', 'climate', 'change', 'immediately', ',', 'from', 'buying', 'a', 'hybrid', 'to', 'inventing', 'a', 'new', ',', 'hotter', 'brand', 'name', 'for', 'global', 'warming', '.']
# ['simplicity', 'sells', ';', 'new', 'york', 'times', 'columnist', 'david', 'pogue', 'takes', 'aim', 'at', 'technology', '’', 's', 'worst', 'interface', '-', 'design', 'offenders', ',', 'and', 'provides', 'encouraging', 'examples', 'of', 'products', 'that', 'get', 'it', 'right', '.', 'to', 'funny', 'things', 'up', ',', 'he', 'bursts', 'into', 'song', '.']
# ['greening', 'the', 'ghetto', ';', 'in', 'an', 'emotionally', 'charged', 'talk', ',', 'macarthur', '-', 'winning', 'activist', 'majora', 'carter', 'details', 'her', 'fight', 'for', 'environmental', 'justice', 'in', 'the', 'south', 'bronx', '--', 'and', 'shows', 'how', 'minority', 'neighborhoods', 'suffer', 'most', 'from', 'flawed', 'urban', 'policy', '.']
# ['the', 'best', 'stats', 'you', "'", 've', 'ever', 'seen', ';', 'you', "'", 've', 'never', 'seen', 'data', 'presented', 'like', 'this', '.', 'with', 'the', 'drama', 'and', 'urgency', 'of', 'a', 'sportscaster', ',', 'statistics', 'guru', 'hans', 'rosling', 'debunks', 'myths', 'about', 'the', 'so', '-', 'called', '"', 'developing', 'world', '."']

# %%
"""
Count how many times each word occured after (n - 1) previous words
:param lines: an iterable of strings with space-separated tokens
:returns: a dictionary { tuple(prefix_tokens): {next_token_1: count_1, next_token_2: count_2}}

When building counts, please consider the following two edge cases:
- if prefix is shorter than (n - 1) tokens, it should be padded with UNK. For n=3,
  empty prefix: "" -> (UNK, UNK)
  short prefix: "the" -> (UNK, the)
  long prefix: "the new approach method" -> (new, approach)
- you should add a special token, EOS, at the end of each sequence
  "... with deep neural networks ." -> (..., with, deep, neural, networks, ., EOS)
  count the probability of this token just like all others.
"""
from collections import defaultdict, Counter

UNK, EOS = '_UNK_', '_EOS_'

def count_ngrams(lines, n=3):
  tokens = tokenize(lines)

  counts = defaultdict(Counter)
  for tok_line in tokens:
    tokens = [UNK] * (n-1) + tok_line + [EOS]
    for i in range(n-1, len(tokens)):
      keys = tuple(tokens[i-n+1:i])
      counts[keys][tokens[i]] += 1

  return counts

# %%
w = count_ngrams(lines, 10)
w
# Out:
# defaultdict(collections.Counter,
#             {('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_'): Counter({'do': 5,
#                       'averting': 1,
#                       'simplicity': 1,
#                       'greening': 1,
#                       'the': 461,
#                       'why': 128,
#                       'letting': 1,
#                       'behind': 3,
#                       'let': 30,
#                       'a': 233,
#                       'my': 65,
#                       'one': 9,
#                       'an': 26,
#                       'improvising': 1,
#                       'simple': 2,
#                       'organic': 2,
#                       'nerdcore': 1,
#                       'meet': 18,
#                       'happiness': 3,
#                       'chemical': 1,
#                       'choice': 1,
#                       'how': 305,
#                       'invest': 2,
#                       'fight': 1,
#                       '8': 1,
#                       'if': 4,
#                       'global': 5,
#                       'dreams': 1,
#                       'photos': 5,
#                       'is': 9,
#                       'progress': 1,
#                       'four': 3,
#                       'everyday': 6,
#                       'unleash': 1,
#                       'in': 8,
#                       'what': 119,
#                       'visual': 1,
#                       'to': 10,
#                       'great': 3,
#                       'singing': 4,
#                       'design': 10,
#                       'art': 9,
#                       'biomimicry': 2,
#                       'sampling': 1,
#                       'software': 1,
#                       'casting': 1,
#                       'cradle': 1,
#                       '"': 27,
#                       'militant': 1,
#                       'technology': 4,
#                       'cape': 1,
#                       'human': 4,
#                       'swim': 1,
#                       'salvation': 1,
#                       'want': 7,
#                       'rethink': 1,
#                       'we': 23,
#                       'tour': 2,
#                       'new': 10,
#                       'i': 14,
#                       'dangerous': 1,
#                       'flip': 1,
#                       'spore': 1,
#                       'visualizing': 3,
#                       'africa': 2,
#                       'aid': 2,
#                       'telling': 1,
#                       'patient': 1,
#                       'luke': 1,
#                       'designing': 3,
#                       '10': 6,
#                       'this': 20,
#                       'life': 11,
#                       'building': 11,
#                       '3': 18,
#                       'laws': 1,
#                       'playing': 4,
#                       'using': 6,
#                       'beauty': 1,
#                       'winning': 1,
#                       '5': 5,
#                       'tales': 2,
#                       'underwater': 1,
#                       'treat': 1,
#                       'rebuilding': 1,
#                       'ted': 2,
#                       'juggle': 1,
#                       'model': 1,
#                       'on': 11,
#                       'sputnik': 1,
#                       'questioning': 1,
#                       'free': 1,
#                       'inventing': 2,
#                       'world': 1,
#                       'where': 7,
#                       'making': 10,
#                       'cern': 1,
#                       'wake': 1,
#                       '6': 2,
#                       'can': 19,
#                       'juggling': 1,
#                       'moving': 2,
#                       'memes': 1,
#                       'archeology': 1,
#                       'turning': 3,
#                       'your': 16,
#                       'robots': 5,
#                       'surprising': 1,
#                       'stephen': 1,
#                       'animate': 1,
#                       'institutions': 1,
#                       'brain': 2,
#                       'blindfold': 1,
#                       'shedding': 1,
#                       'close': 1,
#                       'dog': 1,
#                       'kids': 3,
#                       'dna': 2,
#                       'our': 13,
#                       'once': 1,
#                       'health': 2,
#                       'remember': 1,
#                       'playtime': 1,
#                       'things': 1,
#                       'politics': 1,
#                       'are': 13,
#                       'lessons': 5,
#                       'healing': 1,
#                       'aliens': 1,
#                       'nature': 3,
#                       'flow': 1,
#                       'toys': 1,
#                       'compassion': 2,
#                       'lose': 1,
#                       'expanding': 1,
#                       'walk': 1,
#                       'science': 7,
#                       'tidying': 1,
#                       'fashion': 1,
#                       'demo': 2,
#                       'there': 7,
#                       'taking': 2,
#                       'play': 4,
#                       'digging': 1,
#                       'ways': 1,
#                       'tools': 1,
#                       'genomics': 1,
#                       'hypersonic': 1,
#                       'changing': 2,
#                       'solving': 2,
#                       'fiddling': 1,
#                       'mosquitos': 1,
#                       'toy': 1,
#                       'el': 1,
#                       'join': 1,
#                       'seas': 1,
#                       'conserving': 1,
#                       'learning': 5,
#                       'piano': 1,
#                       'cute': 1,
#                       'high': 2,
#                       'cool': 1,
#                       'poetry': 3,
#                       'extreme': 2,
#                       'military': 1,
#                       'scenes': 1,
#                       'stunning': 2,
#                       'smash': 1,
#                       '9': 1,
#                       'rethinking': 2,
#                       'reporting': 1,
#                       'does': 4,
#                       'comics': 2,
#                       'growing': 3,
#                       'teach': 5,
#                       'anti': 1,
#                       'chaos': 1,
#                       'insights': 1,
#                       'ideas': 2,
#                       'could': 9,
#                       'don': 12,
#                       'odes': 1,
#                       'eco': 1,
#                       'success': 2,
#                       'surgery': 1,
#                       'you': 6,
#                       '17': 1,
#                       'escaping': 1,
#                       '4': 11,
#                       'exploring': 1,
#                       'skin': 1,
#                       'wiring': 2,
#                       'hold': 1,
#                       'adjustable': 1,
#                       'post': 1,
#                       'time': 2,
#                       'hypnotic': 1,
#                       'photographs': 1,
#                       'mapping': 2,
#                       'designers': 1,
#                       'tribal': 1,
#                       'optical': 1,
#                       'claim': 1,
#                       'animating': 1,
#                       'lead': 1,
#                       '1': 2,
#                       'navigating': 1,
#                       'architecture': 5,
#                       'symmetry': 1,
#                       'photographing': 2,
#                       'east': 1,
#                       'learn': 2,
#                       'asia': 1,
#                       'transition': 1,
#                       'dance': 3,
#                       'pop': 2,
#                       'dragonflies': 1,
#                       'metaphorically': 1,
#                       'fusion': 1,
#                       'engineering': 1,
#                       'exposing': 1,
#                       'really': 1,
#                       'stories': 3,
#                       'all': 3,
#                       'rhythm': 1,
#                       'embrace': 4,
#                       'weird': 1,
#                       'augmented': 2,
#                       'innovating': 1,
#                       'watch': 2,
#                       'physics': 1,
#                       'before': 2,
#                       'plug': 1,
#                       'take': 4,
#                       'suspended': 1,
#                       'parrots': 1,
#                       'gaming': 3,
#                       'medical': 1,
#                       'music': 2,
#                       'teaching': 4,
#                       'and': 2,
#                       'when': 11,
#                       'sex': 2,
#                       'every': 4,
#                       'glowing': 1,
#                       'homeopathy': 1,
#                       'bio': 1,
#                       'build': 2,
#                       'political': 2,
#                       'radical': 1,
#                       'computing': 1,
#                       'toward': 2,
#                       'lies': 1,
#                       'social': 4,
#                       'india': 2,
#                       'glimpses': 1,
#                       'math': 3,
#                       'it': 7,
#                       'pay': 2,
#                       'planning': 1,
#                       'bring': 3,
#                       'inside': 7,
#                       'hiv': 2,
#                       'songs': 2,
#                       're': 3,
#                       'pointing': 1,
#                       'sweat': 1,
#                       'debate': 1,
#                       'fighting': 4,
#                       'measuring': 1,
#                       'intricate': 1,
#                       'education': 1,
#                       'legos': 1,
#                       'retrofitting': 1,
#                       'hidden': 4,
#                       'fractals': 1,
#                       'obesity': 1,
#                       'listening': 2,
#                       'superheroes': 1,
#                       'did': 1,
#                       'keep': 1,
#                       'discovering': 1,
#                       'hurdy': 1,
#                       'mothers': 1,
#                       'shh': 1,
#                       'bringing': 1,
#                       'tagging': 1,
#                       'haiti': 1,
#                       'poverty': 2,
#                       'tough': 1,
#                       '"(': 1,
#                       'breakthrough': 1,
#                       'sustainable': 1,
#                       'natural': 1,
#                       'glorious': 1,
#                       '7': 3,
#                       'e': 1,
#                       'saving': 3,
#                       'america': 2,
#                       'simplifying': 1,
#                       'protecting': 2,
#                       'women': 3,
#                       'creative': 2,
#                       'addicted': 1,
#                       'silicon': 1,
#                       'understanding': 2,
#                       'drawing': 1,
#                       'know': 2,
#                       'reviving': 1,
#                       'poems': 1,
#                       'mother': 1,
#                       'reconnecting': 1,
#                       'inspiring': 1,
#                       'curating': 1,
#                       'printing': 1,
#                       'evolution': 1,
#                       'cracking': 1,
#                       'google': 1,
#                       'hands': 1,
#                       'listen': 1,
#                       'looking': 1,
#                       'remaking': 1,
#                       'open': 3,
#                       'transplant': 1,
#                       'beware': 4,
#                       'grow': 1,
#                       'distant': 1,
#                       'animal': 1,
#                       'silk': 1,
#                       'gotta': 1,
#                       'faith': 1,
#                       'authentic': 1,
#                       'wearing': 1,
#                       'break': 1,
#                       'medicine': 2,
#                       'haunting': 1,
#                       'different': 1,
#                       'try': 1,
#                       'cooking': 2,
#                       'caring': 1,
#                       'trial': 1,
#                       'see': 2,
#                       'embracing': 1,
#                       'ending': 1,
#                       'after': 1,
#                       'wireless': 1,
#                       'suddenly': 1,
#                       'finding': 3,
#                       'unintended': 1,
#                       'shake': 1,
#                       'hire': 1,
#                       'welcome': 2,
#                       'selling': 1,
#                       'doodlers': 1,
#                       'filming': 1,
#                       'battling': 1,
#                       'less': 1,
#                       'trusting': 1,
#                       'freeing': 1,
#                       'fbi': 1,
#                       'trust': 1,
#                       'ancient': 1,
#                       'conception': 1,
#                       'fly': 1,
#                       'experiments': 2,
#                       'being': 1,
#                       'living': 2,
#                       'philosophy': 1,
#                       'massive': 1,
#                       'ultrasound': 1,
#                       'color': 2,
#                       'put': 1,
#                       'change': 1,
#                       'be': 4,
#                       'award': 1,
#                       'animations': 1,
#                       'thorium': 1,
#                       'atheism': 1,
#                       'three': 2,
#                       'plant': 1,
#                       'doctors': 1,
#                       'hedonistic': 1,
#                       'treating': 1,
#                       'back': 1,
#                       'hooked': 1,
#                       'non': 1,
#                       'globalizing': 1,
#                       'impossible': 1,
#                       'deaf': 1,
#                       'crowdsource': 1,
#                       'look': 1,
#                       '2600': 1,
#                       'comedy': 1,
#                       'abundance': 1,
#                       'coding': 1,
#                       'questions': 1,
#                       'deep': 3,
#                       'religion': 1,
#                       'beautiful': 2,
#                       'victims': 1,
#                       'yup': 1,
#                       'make': 1,
#                       'from': 2,
#                       'unlock': 1,
#                       'connected': 1,
#                       'half': 1,
#                       'moral': 1,
#                       'older': 1,
#                       'tracking': 2,
#                       'just': 1,
#                       'texting': 1,
#                       'sculpting': 1,
#                       'perspective': 1,
#                       'information': 1,
#                       'unseen': 1,
#                       'feats': 1,
#                       '404': 1,
#                       'beethoven': 1,
#                       'cheap': 1,
#                       'religions': 1,
#                       'beats': 1,
#                       'revealing': 1,
#                       'dancing': 1,
#                       'et': 1,
#                       'will': 2,
#                       'mining': 1,
#                       'archaeology': 1,
#                       'advice': 1,
#                       'reinventing': 1,
#                       'capturing': 1,
#                       'sometimes': 1,
#                       'image': 1,
#                       'imaging': 1,
#                       '(': 1,
#                       'dare': 3,
#                       'strange': 1,
#                       'sculpted': 1,
#                       'energy': 1,
#                       'brilliant': 1,
#                       'mental': 1,
#                       'demand': 2,
#                       'discover': 1,
#                       'between': 1,
#                       'terrorism': 1,
#                       'weaving': 1,
#                       'talk': 1,
#                       'smart': 1,
#                       'online': 2,
#                       'actually': 1,
#                       'metal': 1,
#                       'healthier': 1,
#                       'love': 3,
#                       'teen': 1,
#                       'forget': 4,
#                       'please': 2,
#                       'pool': 1,
#                       'excuse': 1,
#                       'israel': 1,
#                       'ethical': 1,
#                       'biohacking': 1,
#                       'looks': 1,
#                       'fifty': 1,
#                       'hey': 1,
#                       'print': 1,
#                       'who': 5,
#                       'use': 1,
#                       'agile': 1,
#                       'virtual': 1,
#                       'watson': 1,
#                       'parkinson': 1,
#                       'txtng': 1,
#                       'got': 3,
#                       'teachers': 1,
#                       'grit': 1,
#                       'hack': 1,
#                       'prepare': 1,
#                       'violence': 1,
#                       'imagine': 1,
#                       'anatomy': 1,
#                       'reach': 1,
#                       'bluegrass': 1,
#                       'cloudy': 1,
#                       'two': 5,
#                       'dj': 1,
#                       'bitcoin': 1,
#                       'spider': 1,
#                       'better': 2,
#                       'for': 5,
#                       'ingenuity': 1,
#                       'emergency': 1,
#                       'leather': 1,
#                       'confessions': 2,
#                       'psychedelic': 1,
#                       'iran': 1,
#                       'adventures': 2,
#                       'ingenious': 1,
#                       'government': 2,
#                       'massively': 1,
#                       'ecology': 1,
#                       'no': 2,
#                       'body': 1,
#                       'depression': 1,
#                       'never': 1,
#                       'profit': 1,
#                       'so': 1,
#                       'his': 1,
#                       'as': 1,
#                       'puppies': 1,
#                       'paper': 1,
#                       'synthetic': 1,
#                       'here': 1,
#                       'zombie': 1,
#                       'should': 4,
#                       'autism': 1,
#                       'get': 2,
#                       'save': 1,
#                       'hackers': 1,
#                       'which': 1,
#                       'sculptures': 1,
#                       'own': 1,
#                       'depressed': 1,
#                       'crop': 1,
#                       'find': 1,
#                       'wry': 1,
#                       'big': 1,
#                       '“': 1,
#                       'sanitation': 1,
#                       'yes': 1,
#                       'humble': 1,
#                       'tiny': 1,
#                       'fighters': 1,
#                       'trash': 1,
#                       'go': 1,
#                       'happy': 1,
#                       'hopeful': 1,
#                       'humanity': 1,
#                       'old': 1,
#                       'think': 1,
#                       'everyone': 1,
#                       'programming': 1,
#                       'magical': 1,
#                       'physical': 1,
#                       'chimps': 1,
#                       'gorgeous': 1,
#                       'everything': 2,
#                       'street': 1,
#                       'these': 1,
#                       'falling': 1,
#                       'alzheimer': 1,
#                       'climate': 1,
#                       'soon': 1,
#                       'home': 1,
#                       'refugees': 1,
#                       'governments': 1,
#                       'have': 1,
#                       'capitalism': 1,
#                       'glow': 1,
#                       'special': 1,
#                       'economic': 1,
#                       'shape': 1,
#                       'dive': 1,
#                       'uber': 1,
#                       'wisdom': 1,
#                       'hunting': 2,
#                       'insightful': 1,
#                       'pirates': 1,
#                       'gene': 1,
#                       'good': 1,
#                       'drawings': 1,
#                       'clues': 1,
#                       'immigrant': 1,
#                       'ballroom': 1,
#                       'machine': 1,
#                       'enough': 1,
#                       'islamophobia': 1,
#                       'easy': 1,
#                       'help': 2,
#                       'maps': 1,
#                       'say': 1,
#                       'buildings': 1,
#                       'nationalism': 1,
#                       'smelfies': 1,
#                       'lifelike': 1,
#                       'asking': 1,
#                       'addiction': 1,
#                       'thoughts': 1,
#                       'am': 1,
#                       '12': 1,
#                       'doesn': 1,
#                       'lifesaving': 1,
#                       'hamilton': 1,
#                       'courage': 1,
#                       'fun': 1,
#                       'would': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'do'): Counter({'schools': 1,
#                       'the': 1,
#                       'what': 1,
#                       'we': 1,
#                       'kids': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'do',
#               'schools'): Counter({'kill': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'do',
#               'schools',
#               'kill'): Counter({'creativity': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'do',
#               'schools',
#               'kill',
#               'creativity'): Counter({'?': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'do',
#               'schools',
#               'kill',
#               'creativity',
#               '?'): Counter({';': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'do',
#               'schools',
#               'kill',
#               'creativity',
#               '?',
#               ';'): Counter({'sir': 1}),
#              ('_UNK_',
#               '_UNK_',
#               'do',
#               'schools',
#               'kill',
#               'creativity',
#               '?',
#               ';',
#               'sir'): Counter({'ken': 1}),
#              ('_UNK_',
#               'do',
#               'schools',
#               'kill',
#               'creativity',
#               '?',
#               ';',
#               'sir',
#               'ken'): Counter({'robinson': 1}),
#              ('do',
#               'schools',
#               'kill',
#               'creativity',
#               '?',
#               ';',
#               'sir',
#               'ken',
#               'robinson'): Counter({'makes': 1}),
#              ('schools',
#               'kill',
#               'creativity',
#               '?',
#               ';',
#               'sir',
#               'ken',
#               'robinson',
#               'makes'): Counter({'an': 1}),
#              ('kill',
#               'creativity',
#               '?',
#               ';',
#               'sir',
#               'ken',
#               'robinson',
#               'makes',
#               'an'): Counter({'entertaining': 1}),
#              ('creativity',
#               '?',
#               ';',
#               'sir',
#               'ken',
#               'robinson',
#               'makes',
#               'an',
#               'entertaining'): Counter({'and': 1}),
#              ('?',
#               ';',
#               'sir',
#               'ken',
#               'robinson',
#               'makes',
#               'an',
#               'entertaining',
#               'and'): Counter({'profoundly': 1}),
#              (';',
#               'sir',
#               'ken',
#               'robinson',
#               'makes',
#               'an',
#               'entertaining',
#               'and',
#               'profoundly'): Counter({'moving': 1}),
#              ('sir',
#               'ken',
#               'robinson',
#               'makes',
#               'an',
#               'entertaining',
#               'and',
#               'profoundly',
#               'moving'): Counter({'case': 1}),
#              ('ken',
#               'robinson',
#               'makes',
#               'an',
#               'entertaining',
#               'and',
#               'profoundly',
#               'moving',
#               'case'): Counter({'for': 1}),
#              ('robinson',
#               'makes',
#               'an',
#               'entertaining',
#               'and',
#               'profoundly',
#               'moving',
#               'case',
#               'for'): Counter({'creating': 1}),
#              ('makes',
#               'an',
#               'entertaining',
#               'and',
#               'profoundly',
#               'moving',
#               'case',
#               'for',
#               'creating'): Counter({'an': 1}),
#              ('an',
#               'entertaining',
#               'and',
#               'profoundly',
#               'moving',
#               'case',
#               'for',
#               'creating',
#               'an'): Counter({'education': 1}),
#              ('entertaining',
#               'and',
#               'profoundly',
#               'moving',
#               'case',
#               'for',
#               'creating',
#               'an',
#               'education'): Counter({'system': 1}),
#              ('and',
#               'profoundly',
#               'moving',
#               'case',
#               'for',
#               'creating',
#               'an',
#               'education',
#               'system'): Counter({'that': 1}),
#              ('profoundly',
#               'moving',
#               'case',
#               'for',
#               'creating',
#               'an',
#               'education',
#               'system',
#               'that'): Counter({'nurtures': 1}),
#              ('moving',
#               'case',
#               'for',
#               'creating',
#               'an',
#               'education',
#               'system',
#               'that',
#               'nurtures'): Counter({'(': 1}),
#              ('case',
#               'for',
#               'creating',
#               'an',
#               'education',
#               'system',
#               'that',
#               'nurtures',
#               '('): Counter({'rather': 1}),
#              ('for',
#               'creating',
#               'an',
#               'education',
#               'system',
#               'that',
#               'nurtures',
#               '(',
#               'rather'): Counter({'than': 1}),
#              ('creating',
#               'an',
#               'education',
#               'system',
#               'that',
#               'nurtures',
#               '(',
#               'rather',
#               'than'): Counter({'undermines': 1}),
#              ('an',
#               'education',
#               'system',
#               'that',
#               'nurtures',
#               '(',
#               'rather',
#               'than',
#               'undermines'): Counter({')': 1}),
#              ('education',
#               'system',
#               'that',
#               'nurtures',
#               '(',
#               'rather',
#               'than',
#               'undermines',
#               ')'): Counter({'creativity': 1}),
#              ('system',
#               'that',
#               'nurtures',
#               '(',
#               'rather',
#               'than',
#               'undermines',
#               ')',
#               'creativity'): Counter({'.': 1}),
#              ('that',
#               'nurtures',
#               '(',
#               'rather',
#               'than',
#               'undermines',
#               ')',
#               'creativity',
#               '.'): Counter({'_EOS_': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'averting'): Counter({'the': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'averting',
#               'the'): Counter({'climate': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'averting',
#               'the',
#               'climate'): Counter({'crisis': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'averting',
#               'the',
#               'climate',
#               'crisis'): Counter({';': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'averting',
#               'the',
#               'climate',
#               'crisis',
#               ';'): Counter({'with': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'averting',
#               'the',
#               'climate',
#               'crisis',
#               ';',
#               'with'): Counter({'the': 1}),
#              ('_UNK_',
#               '_UNK_',
#               'averting',
#               'the',
#               'climate',
#               'crisis',
#               ';',
#               'with',
#               'the'): Counter({'same': 1}),
#              ('_UNK_',
#               'averting',
#               'the',
#               'climate',
#               'crisis',
#               ';',
#               'with',
#               'the',
#               'same'): Counter({'humor': 1}),
#              ('averting',
#               'the',
#               'climate',
#               'crisis',
#               ';',
#               'with',
#               'the',
#               'same',
#               'humor'): Counter({'and': 1}),
#              ('the',
#               'climate',
#               'crisis',
#               ';',
#               'with',
#               'the',
#               'same',
#               'humor',
#               'and'): Counter({'humanity': 1}),
#              ('climate',
#               'crisis',
#               ';',
#               'with',
#               'the',
#               'same',
#               'humor',
#               'and',
#               'humanity'): Counter({'he': 1}),
#              ('crisis',
#               ';',
#               'with',
#               'the',
#               'same',
#               'humor',
#               'and',
#               'humanity',
#               'he'): Counter({'exuded': 1}),
#              (';',
#               'with',
#               'the',
#               'same',
#               'humor',
#               'and',
#               'humanity',
#               'he',
#               'exuded'): Counter({'in': 1}),
#              ('with',
#               'the',
#               'same',
#               'humor',
#               'and',
#               'humanity',
#               'he',
#               'exuded',
#               'in'): Counter({'"': 1}),
#              ('the',
#               'same',
#               'humor',
#               'and',
#               'humanity',
#               'he',
#               'exuded',
#               'in',
#               '"'): Counter({'an': 1}),
#              ('same',
#               'humor',
#               'and',
#               'humanity',
#               'he',
#               'exuded',
#               'in',
#               '"',
#               'an'): Counter({'inconvenient': 1}),
#              ('humor',
#               'and',
#               'humanity',
#               'he',
#               'exuded',
#               'in',
#               '"',
#               'an',
#               'inconvenient'): Counter({'truth': 1}),
#              ('and',
#               'humanity',
#               'he',
#               'exuded',
#               'in',
#               '"',
#               'an',
#               'inconvenient',
#               'truth'): Counter({',"': 1}),
#              ('humanity',
#               'he',
#               'exuded',
#               'in',
#               '"',
#               'an',
#               'inconvenient',
#               'truth',
#               ',"'): Counter({'al': 1}),
#              ('he',
#               'exuded',
#               'in',
#               '"',
#               'an',
#               'inconvenient',
#               'truth',
#               ',"',
#               'al'): Counter({'gore': 1}),
#              ('exuded',
#               'in',
#               '"',
#               'an',
#               'inconvenient',
#               'truth',
#               ',"',
#               'al',
#               'gore'): Counter({'spells': 1}),
#              ('in',
#               '"',
#               'an',
#               'inconvenient',
#               'truth',
#               ',"',
#               'al',
#               'gore',
#               'spells'): Counter({'out': 1}),
#              ('"',
#               'an',
#               'inconvenient',
#               'truth',
#               ',"',
#               'al',
#               'gore',
#               'spells',
#               'out'): Counter({'15': 1}),
#              ('an',
#               'inconvenient',
#               'truth',
#               ',"',
#               'al',
#               'gore',
#               'spells',
#               'out',
#               '15'): Counter({'ways': 1}),
#              ('inconvenient',
#               'truth',
#               ',"',
#               'al',
#               'gore',
#               'spells',
#               'out',
#               '15',
#               'ways'): Counter({'that': 1}),
#              ('truth',
#               ',"',
#               'al',
#               'gore',
#               'spells',
#               'out',
#               '15',
#               'ways',
#               'that'): Counter({'individuals': 1}),
#              (',"',
#               'al',
#               'gore',
#               'spells',
#               'out',
#               '15',
#               'ways',
#               'that',
#               'individuals'): Counter({'can': 1}),
#              ('al',
#               'gore',
#               'spells',
#               'out',
#               '15',
#               'ways',
#               'that',
#               'individuals',
#               'can'): Counter({'address': 1}),
#              ('gore',
#               'spells',
#               'out',
#               '15',
#               'ways',
#               'that',
#               'individuals',
#               'can',
#               'address'): Counter({'climate': 1}),
#              ('spells',
#               'out',
#               '15',
#               'ways',
#               'that',
#               'individuals',
#               'can',
#               'address',
#               'climate'): Counter({'change': 1}),
#              ('out',
#               '15',
#               'ways',
#               'that',
#               'individuals',
#               'can',
#               'address',
#               'climate',
#               'change'): Counter({'immediately': 1}),
#              ('15',
#               'ways',
#               'that',
#               'individuals',
#               'can',
#               'address',
#               'climate',
#               'change',
#               'immediately'): Counter({',': 1}),
#              ('ways',
#               'that',
#               'individuals',
#               'can',
#               'address',
#               'climate',
#               'change',
#               'immediately',
#               ','): Counter({'from': 1}),
#              ('that',
#               'individuals',
#               'can',
#               'address',
#               'climate',
#               'change',
#               'immediately',
#               ',',
#               'from'): Counter({'buying': 1}),
#              ('individuals',
#               'can',
#               'address',
#               'climate',
#               'change',
#               'immediately',
#               ',',
#               'from',
#               'buying'): Counter({'a': 1}),
#              ('can',
#               'address',
#               'climate',
#               'change',
#               'immediately',
#               ',',
#               'from',
#               'buying',
#               'a'): Counter({'hybrid': 1}),
#              ('address',
#               'climate',
#               'change',
#               'immediately',
#               ',',
#               'from',
#               'buying',
#               'a',
#               'hybrid'): Counter({'to': 1}),
#              ('climate',
#               'change',
#               'immediately',
#               ',',
#               'from',
#               'buying',
#               'a',
#               'hybrid',
#               'to'): Counter({'inventing': 1}),
#              ('change',
#               'immediately',
#               ',',
#               'from',
#               'buying',
#               'a',
#               'hybrid',
#               'to',
#               'inventing'): Counter({'a': 1}),
#              ('immediately',
#               ',',
#               'from',
#               'buying',
#               'a',
#               'hybrid',
#               'to',
#               'inventing',
#               'a'): Counter({'new': 1}),
#              (',',
#               'from',
#               'buying',
#               'a',
#               'hybrid',
#               'to',
#               'inventing',
#               'a',
#               'new'): Counter({',': 1}),
#              ('from',
#               'buying',
#               'a',
#               'hybrid',
#               'to',
#               'inventing',
#               'a',
#               'new',
#               ','): Counter({'hotter': 1}),
#              ('buying',
#               'a',
#               'hybrid',
#               'to',
#               'inventing',
#               'a',
#               'new',
#               ',',
#               'hotter'): Counter({'brand': 1}),
#              ('a',
#               'hybrid',
#               'to',
#               'inventing',
#               'a',
#               'new',
#               ',',
#               'hotter',
#               'brand'): Counter({'name': 1}),
#              ('hybrid',
#               'to',
#               'inventing',
#               'a',
#               'new',
#               ',',
#               'hotter',
#               'brand',
#               'name'): Counter({'for': 1}),
#              ('to',
#               'inventing',
#               'a',
#               'new',
#               ',',
#               'hotter',
#               'brand',
#               'name',
#               'for'): Counter({'global': 1}),
#              ('inventing',
#               'a',
#               'new',
#               ',',
#               'hotter',
#               'brand',
#               'name',
#               'for',
#               'global'): Counter({'warming': 1}),
#              ('a',
#               'new',
#               ',',
#               'hotter',
#               'brand',
#               'name',
#               'for',
#               'global',
#               'warming'): Counter({'.': 1}),
#              ('new',
#               ',',
#               'hotter',
#               'brand',
#               'name',
#               'for',
#               'global',
#               'warming',
#               '.'): Counter({'_EOS_': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'simplicity'): Counter({'sells': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'simplicity',
#               'sells'): Counter({';': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'simplicity',
#               'sells',
#               ';'): Counter({'new': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'simplicity',
#               'sells',
#               ';',
#               'new'): Counter({'york': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'simplicity',
#               'sells',
#               ';',
#               'new',
#               'york'): Counter({'times': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'simplicity',
#               'sells',
#               ';',
#               'new',
#               'york',
#               'times'): Counter({'columnist': 1}),
#              ('_UNK_',
#               '_UNK_',
#               'simplicity',
#               'sells',
#               ';',
#               'new',
#               'york',
#               'times',
#               'columnist'): Counter({'david': 1}),
#              ('_UNK_',
#               'simplicity',
#               'sells',
#               ';',
#               'new',
#               'york',
#               'times',
#               'columnist',
#               'david'): Counter({'pogue': 1}),
#              ('simplicity',
#               'sells',
#               ';',
#               'new',
#               'york',
#               'times',
#               'columnist',
#               'david',
#               'pogue'): Counter({'takes': 1}),
#              ('sells',
#               ';',
#               'new',
#               'york',
#               'times',
#               'columnist',
#               'david',
#               'pogue',
#               'takes'): Counter({'aim': 1}),
#              (';',
#               'new',
#               'york',
#               'times',
#               'columnist',
#               'david',
#               'pogue',
#               'takes',
#               'aim'): Counter({'at': 1}),
#              ('new',
#               'york',
#               'times',
#               'columnist',
#               'david',
#               'pogue',
#               'takes',
#               'aim',
#               'at'): Counter({'technology': 1}),
#              ('york',
#               'times',
#               'columnist',
#               'david',
#               'pogue',
#               'takes',
#               'aim',
#               'at',
#               'technology'): Counter({'’': 1}),
#              ('times',
#               'columnist',
#               'david',
#               'pogue',
#               'takes',
#               'aim',
#               'at',
#               'technology',
#               '’'): Counter({'s': 1}),
#              ('columnist',
#               'david',
#               'pogue',
#               'takes',
#               'aim',
#               'at',
#               'technology',
#               '’',
#               's'): Counter({'worst': 1}),
#              ('david',
#               'pogue',
#               'takes',
#               'aim',
#               'at',
#               'technology',
#               '’',
#               's',
#               'worst'): Counter({'interface': 1}),
#              ('pogue',
#               'takes',
#               'aim',
#               'at',
#               'technology',
#               '’',
#               's',
#               'worst',
#               'interface'): Counter({'-': 1}),
#              ('takes',
#               'aim',
#               'at',
#               'technology',
#               '’',
#               's',
#               'worst',
#               'interface',
#               '-'): Counter({'design': 1}),
#              ('aim',
#               'at',
#               'technology',
#               '’',
#               's',
#               'worst',
#               'interface',
#               '-',
#               'design'): Counter({'offenders': 1}),
#              ('at',
#               'technology',
#               '’',
#               's',
#               'worst',
#               'interface',
#               '-',
#               'design',
#               'offenders'): Counter({',': 1}),
#              ('technology',
#               '’',
#               's',
#               'worst',
#               'interface',
#               '-',
#               'design',
#               'offenders',
#               ','): Counter({'and': 1}),
#              ('’',
#               's',
#               'worst',
#               'interface',
#               '-',
#               'design',
#               'offenders',
#               ',',
#               'and'): Counter({'provides': 1}),
#              ('s',
#               'worst',
#               'interface',
#               '-',
#               'design',
#               'offenders',
#               ',',
#               'and',
#               'provides'): Counter({'encouraging': 1}),
#              ('worst',
#               'interface',
#               '-',
#               'design',
#               'offenders',
#               ',',
#               'and',
#               'provides',
#               'encouraging'): Counter({'examples': 1}),
#              ('interface',
#               '-',
#               'design',
#               'offenders',
#               ',',
#               'and',
#               'provides',
#               'encouraging',
#               'examples'): Counter({'of': 1}),
#              ('-',
#               'design',
#               'offenders',
#               ',',
#               'and',
#               'provides',
#               'encouraging',
#               'examples',
#               'of'): Counter({'products': 1}),
#              ('design',
#               'offenders',
#               ',',
#               'and',
#               'provides',
#               'encouraging',
#               'examples',
#               'of',
#               'products'): Counter({'that': 1}),
#              ('offenders',
#               ',',
#               'and',
#               'provides',
#               'encouraging',
#               'examples',
#               'of',
#               'products',
#               'that'): Counter({'get': 1}),
#              (',',
#               'and',
#               'provides',
#               'encouraging',
#               'examples',
#               'of',
#               'products',
#               'that',
#               'get'): Counter({'it': 1}),
#              ('and',
#               'provides',
#               'encouraging',
#               'examples',
#               'of',
#               'products',
#               'that',
#               'get',
#               'it'): Counter({'right': 1}),
#              ('provides',
#               'encouraging',
#               'examples',
#               'of',
#               'products',
#               'that',
#               'get',
#               'it',
#               'right'): Counter({'.': 1}),
#              ('encouraging',
#               'examples',
#               'of',
#               'products',
#               'that',
#               'get',
#               'it',
#               'right',
#               '.'): Counter({'to': 1}),
#              ('examples',
#               'of',
#               'products',
#               'that',
#               'get',
#               'it',
#               'right',
#               '.',
#               'to'): Counter({'funny': 1}),
#              ('of',
#               'products',
#               'that',
#               'get',
#               'it',
#               'right',
#               '.',
#               'to',
#               'funny'): Counter({'things': 1}),
#              ('products',
#               'that',
#               'get',
#               'it',
#               'right',
#               '.',
#               'to',
#               'funny',
#               'things'): Counter({'up': 1}),
#              ('that',
#               'get',
#               'it',
#               'right',
#               '.',
#               'to',
#               'funny',
#               'things',
#               'up'): Counter({',': 1}),
#              ('get',
#               'it',
#               'right',
#               '.',
#               'to',
#               'funny',
#               'things',
#               'up',
#               ','): Counter({'he': 1}),
#              ('it',
#               'right',
#               '.',
#               'to',
#               'funny',
#               'things',
#               'up',
# ...
#               'tells',
#               'us',
#               'what'): Counter({'he': 1}),
#              ('nerdcore',
#               'standup',
#               'routine',
#               ',',
#               'then',
#               'tells',
#               'us',
#               'what',
#               'he'): Counter({"'": 1}),
#              ('standup',
#               'routine',
#               ',',
#               'then',
#               'tells',
#               'us',
#               'what',
#               'he',
#               "'"): Counter({'s': 1}),
#              ('routine',
#               ',',
#               'then',
#               'tells',
#               'us',
#               'what',
#               'he',
#               "'",
#               's'): Counter({'seriously': 1}),
#              (',',
#               'then',
#               'tells',
#               'us',
#               'what',
#               'he',
#               "'",
#               's',
#               'seriously'): Counter({'passionate': 1}),
#              ('then',
#               'tells',
#               'us',
#               'what',
#               'he',
#               "'",
#               's',
#               'seriously',
#               'passionate'): Counter({'about': 1}),
#              ('tells',
#               'us',
#               'what',
#               'he',
#               "'",
#               's',
#               'seriously',
#               'passionate',
#               'about'): Counter({':': 1}),
#              ('us',
#               'what',
#               'he',
#               "'",
#               's',
#               'seriously',
#               'passionate',
#               'about',
#               ':'): Counter({'helping': 1}),
#              ('what',
#               'he',
#               "'",
#               's',
#               'seriously',
#               'passionate',
#               'about',
#               ':',
#               'helping'): Counter({'people': 1}),
#              ('he',
#               "'",
#               's',
#               'seriously',
#               'passionate',
#               'about',
#               ':',
#               'helping',
#               'people'): Counter({'create': 1}),
#              ("'",
#               's',
#               'seriously',
#               'passionate',
#               'about',
#               ':',
#               'helping',
#               'people',
#               'create'): Counter({'and': 1}),
#              ('s',
#               'seriously',
#               'passionate',
#               'about',
#               ':',
#               'helping',
#               'people',
#               'create',
#               'and'): Counter({'interact': 1}),
#              ('seriously',
#               'passionate',
#               'about',
#               ':',
#               'helping',
#               'people',
#               'create',
#               'and',
#               'interact'): Counter({'using': 1}),
#              ('passionate',
#               'about',
#               ':',
#               'helping',
#               'people',
#               'create',
#               'and',
#               'interact',
#               'using'): Counter({'simple': 1}),
#              ('about',
#               ':',
#               'helping',
#               'people',
#               'create',
#               'and',
#               'interact',
#               'using',
#               'simple'): Counter({',': 1}),
#              (':',
#               'helping',
#               'people',
#               'create',
#               'and',
#               'interact',
#               'using',
#               'simple',
#               ','): Counter({'addictive': 1}),
#              ('helping',
#               'people',
#               'create',
#               'and',
#               'interact',
#               'using',
#               'simple',
#               ',',
#               'addictive'): Counter({'web': 1}),
#              ('people',
#               'create',
#               'and',
#               'interact',
#               'using',
#               'simple',
#               ',',
#               'addictive',
#               'web'): Counter({'tools': 1}),
#              ('create',
#               'and',
#               'interact',
#               'using',
#               'simple',
#               ',',
#               'addictive',
#               'web',
#               'tools'): Counter({'.': 1}),
#              ('and',
#               'interact',
#               'using',
#               'simple',
#               ',',
#               'addictive',
#               'web',
#               'tools',
#               '.'): Counter({'_EOS_': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'meet'): Counter({'the': 10,
#                       'milo': 1,
#                       'e': 1,
#                       'rezero': 1,
#                       'your': 1,
#                       'brck': 1,
#                       'global': 1,
#                       'a': 1,
#                       'spot': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'meet',
#               'the'): Counter({'founder': 1,
#                       'future': 1,
#                       'sixthsense': 1,
#                       'water': 1,
#                       'robots': 1,
#                       'mom': 1,
#                       'women': 1,
#                       'dazzling': 1,
#                       'inventor': 1,
#                       'microscopic': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'meet',
#               'the',
#               'founder'): Counter({'of': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'meet',
#               'the',
#               'founder',
#               'of'): Counter({'the': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'meet',
#               'the',
#               'founder',
#               'of',
#               'the'): Counter({'blog': 1}),
#              ('_UNK_',
#               '_UNK_',
#               '_UNK_',
#               'meet',
#               'the',
#               'founder',
#               'of',
#               'the',
#               'blog'): Counter({'revolution': 1}),
#              ('_UNK_',
#               '_UNK_',
#               'meet',
#               'the',
#               'founder',
#               'of',
#               'the',
#               'blog',
#               'revolution'): Counter({';': 1}),
#              ('_UNK_',
#               'meet',
#               'the',
#               'founder',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ';'): Counter({'the': 1}),
#              ('meet',
#               'the',
#               'founder',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ';',
#               'the'): Counter({'founding': 1}),
#              ('the',
#               'founder',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ';',
#               'the',
#               'founding'): Counter({'mother': 1}),
#              ('founder',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ';',
#               'the',
#               'founding',
#               'mother'): Counter({'of': 1}),
#              ('of',
#               'the',
#               'blog',
#               'revolution',
#               ';',
#               'the',
#               'founding',
#               'mother',
#               'of'): Counter({'the': 1}),
#              ('the',
#               'blog',
#               'revolution',
#               ';',
#               'the',
#               'founding',
#               'mother',
#               'of',
#               'the'): Counter({'blog': 1}),
#              ('blog',
#               'revolution',
#               ';',
#               'the',
#               'founding',
#               'mother',
#               'of',
#               'the',
#               'blog'): Counter({'revolution': 1}),
#              ('revolution',
#               ';',
#               'the',
#               'founding',
#               'mother',
#               'of',
#               'the',
#               'blog',
#               'revolution'): Counter({',': 1}),
#              (';',
#               'the',
#               'founding',
#               'mother',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ','): Counter({'movable': 1}),
#              ('the',
#               'founding',
#               'mother',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ',',
#               'movable'): Counter({'type': 1}),
#              ('founding',
#               'mother',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ',',
#               'movable',
#               'type'): Counter({"'": 1}),
#              ('mother',
#               'of',
#               'the',
#               'blog',
#               'revolution',
#               ',',
#               'movable',
#               'type',
#               "'"): Counter({'s': 1}),
#              ('of',
#               'the',
#               'blog',
#               'revolution',
#               ',',
#               'movable',
#               'type',
#               "'",
#               's'): Counter({'mena': 1}),
#              ('the',
#               'blog',
#               'revolution',
#               ',',
#               'movable',
#               'type',
#               "'",
#               's',
#               'mena'): Counter({'trott': 1}),
#              ('blog',
#               'revolution',
#               ',',
#               'movable',
#               'type',
#               "'",
#               's',
#               'mena',
#               'trott'): Counter({',': 1}),
#              ('revolution',
#               ',',
#               'movable',
#               'type',
#               "'",
#               's',
#               'mena',
#               'trott',
#               ','): Counter({'talks': 1}),
#              (',',
#               'movable',
#               'type',
#               "'",
#               's',
#               'mena',
#               'trott',
#               ',',
#               'talks'): Counter({'about': 1}),
#              ('movable',
#               'type',
#               "'",
#               's',
#               'mena',
#               'trott',
#               ',',
#               'talks',
#               'about'): Counter({'the': 1}),
#              ('type',
#               "'",
#               's',
#               'mena',
#               'trott',
#               ',',
#               'talks',
#               'about',
#               'the'): Counter({'early': 1}),
#              ("'",
#               's',
#               'mena',
#               'trott',
#               ',',
#               'talks',
#               'about',
#               'the',
#               'early'): Counter({'days': 1}),
#              ('s',
#               'mena',
#               'trott',
#               ',',
#               'talks',
#               'about',
#               'the',
#               'early',
#               'days'): Counter({'of': 1}),
#              ('mena',
#               'trott',
#               ',',
#               'talks',
#               'about',
#               'the',
#               'early',
#               'days',
#               'of'): Counter({'blogging': 1}),
#              ('trott',
#               ',',
#               'talks',
#               'about',
#               'the',
#               'early',
#               'days',
#               'of',
#               'blogging'): Counter({',': 1}),
#              (',',
#               'talks',
#               'about',
#               'the',
#               'early',
#               'days',
#               'of',
#               'blogging',
#               ','): Counter({'when': 1}),
#              ('talks',
#               'about',
#               'the',
#               'early',
#               'days',
#               'of',
#               'blogging',
#               ',',
#               'when'): Counter({'she': 1}),
#              ('about',
#               'the',
#               'early',
#               'days',
#               'of',
#               'blogging',
#               ',',
#               'when',
#               'she'): Counter({'realized': 1}),
#              ('the',
#               'early',
#               'days',
#               'of',
#               'blogging',
#               ',',
#               'when',
#               'she',
#               'realized'): Counter({'that': 1}),
#              ('early',
#               'days',
#               'of',
#               'blogging',
#               ',',
#               'when',
#               'she',
#               'realized',
#               'that'): Counter({'giving': 1}),
#              ('days',
#               'of',
#               'blogging',
#               ',',
#               'when',
#               'she',
#               'realized',
#               'that',
#               'giving'): Counter({'regular': 1}),
#              ('of',
#               'blogging',
#               ',',
#               'when',
#               'she',
#               'realized',
#               'that',
#               'giving',
#               'regular'): Counter({'people': 1}),
#              ('blogging',
#               ',',
#               'when',
#               'she',
#               'realized',
#               'that',
#               'giving',
#               'regular',
#               'people'): Counter({'the': 1}),
#              (',',
#               'when',
#               'she',
#               'realized',
#               'that',
#               'giving',
#               'regular',
#               'people',
#               'the'): Counter({'power': 1}),
#              ('when',
#               'she',
#               'realized',
#               'that',
#               'giving',
#               'regular',
#               'people',
#               'the',
#               'power'): Counter({'to': 1}),
#              ('she',
#               'realized',
#               'that',
#               'giving',
#               'regular',
#               'people',
#               'the',
#               'power',
#               'to'): Counter({'share': 1}),
#              ('realized',
#               'that',
#               'giving',
#               'regular',
#               'people',
#               'the',
#               'power',
#               'to',
#               'share'): Counter({'our': 1}),
#              ('that',
#               'giving',
#               'regular',
#               'people',
#               'the',
#               'power',
#               'to',
#               'share',
#               'our'): Counter({'lives': 1}),
#              ('giving',
#               'regular',
#               'people',
#               'the',
#               'power',
#               'to',
#               'share',
#               'our',
#               'lives'): Counter({'online': 1}),
#              ('regular',
#               'people',
#               'the',
#               'power',
#               'to',
#               'share',
#               'our',
#               'lives',
#               'online'): Counter({'is': 1}),
#              ('people',
#               'the',
#               'power',
#               'to',
#               'share',
#               'our',
#               'lives',
#               'online',
#               'is'): Counter({'the': 1}),
#              ('the',
#               'power',
#               'to',
#               'share',
#               'our',
#               'lives',
#               'online',
#               'is',
#               'the'): Counter({'key': 1}),
#              ('power',
#               'to',
#               'share',
#               'our',
#               'lives',
#               'online',
#               'is',
#               'the',
#               'key'): Counter({'to': 1}),
#              ('to',
#               'share',
#               'our',
#               'lives',
#               'online',
#               'is',
#               'the',
#               'key',
#               'to'): Counter({'building': 1}),
#              ...})

# %%
type(w)
# Out:
# collections.defaultdict

# %%
def get_possible_next_tokens(prefix, n=3):
    """
    :param prefix: string with space - separated prefix tokens
    :returns: a dictionary {token : it's probability} for all tokens with positive probabilities
    """
    tokenizer = WordPunctTokenizer()
    prefix = tokenizer.tokenize(prefix.lower())
    prefix = prefix[len(prefix)-n+1:len(prefix)]
    probs = w[tuple(prefix)]
    total_prob = sum(probs.values())
    print(total_prob)

# %%
d=get_possible_next_tokens("to end")
# Out:
# 0

# %%
class NGramModel:
  def __init__(self, input, n=3):
        """
        :param n: computes probability of next token given (n - 1) previous words
        :param input: an iterable of strings with space-separated tokens
        """
        assert n > 0
        self.n = n
        self.ngrams = count_ngrams(input, self.n)
        self.probs = defaultdict(Counter)

  def get_possible_next_tokens(self, prefix):
          """
          :param prefix: string with space - separated prefix tokens
          :returns: a dictionary {token : it's probability} for all tokens with positive probabilities
          """
          tokenizer = WordPunctTokenizer()
          prefix = tokenizer.tokenize(prefix.lower())

          prefix = prefix[max(0, len(prefix) - self.n + 1):]
          prefix = [ UNK ] * (self.n - 1 - len(prefix)) + prefix
          probs = self.ngrams[tuple(prefix)]
          all_probs = sum(probs.values())
          probs = {key: probs[key]/all_probs for key in probs}
          return probs

  def get_next_token_prob(self, prefix, next_token):
          """
          :param prefix: string with space-separated prefix tokens
          :param next_token: the next token to predict probability for
          :returns: P(next_token|prefix) a single number, 0 <= P <= 1
          """
          return self.get_possible_next_tokens(prefix).get(next_token, 0)

# %%
lm = NGramModel(lines, 10)

# %%
print(lm.get_possible_next_tokens("end of the"))
# Out:
# {}

# %%
def get_next_token(lm, prefix, temperature=1.0):
    """
    return next token after prefix;
    :param temperature: samples proportionally to lm probabilities ^ (1 / temperature)
        if temperature == 0, always takes most likely token. Break ties arbitrarily.
    """
    prefix_probabilities = lm.get_possible_next_tokens(prefix)
    if temperature == 0.0:
      next_token = max(prefix_probabilities, key=prefix_probabilities.get)
      return next_token
    softened_probabilities = {word: prob ** (1 / temperature) for word, prob in prefix_probabilities.items()}
    normalization_term = sum(softened_probabilities.values())
    normalized_probabilities = {word: prob / normalization_term for word, prob in softened_probabilities.items()}
    next_token = np.random.choice(list(normalized_probabilities.keys()), p=list(normalized_probabilities.values()))

    return next_token
    # return max(prob, key=prob.get)

# %%
x = get_next_token(lm, "end of the", 1)
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-234-9c52d0811ec5> in <cell line: 1>()
# ----> 1 x = get_next_token(lm, "end of the", 1)
#       2 x
#
# <ipython-input-233-29152344745f> in get_next_token(lm, prefix, temperature)
#      12     normalization_term = sum(softened_probabilities.values())
#      13     normalized_probabilities = {word: prob / normalization_term for word, prob in softened_probabilities.items()}
# ---> 14     next_token = np.random.choice(list(normalized_probabilities.keys()), p=list(normalized_probabilities.values()))
#      15
#      16     return next_token
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: 'a' cannot be empty unless no samples are taken

# %%
prefix = 'science'

def generate(prefix):
  for i in range(100):
      prefix += ' ' + get_next_token(lm, prefix, 0.7)
      if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
          break
  text = prefix
  return text[:len(text)-5]

print(generate(prefix))

# %%
#@title Fully defined class

class NGramModel:
  def __init__(self, input, n=3):
        """
        :param n: computes probability of next token given (n - 1) previous words
        :param input: an iterable of strings with space-separated tokens
        """
        assert n > 0
        self.n = n
        self.ngrams = self.count_ngrams_inclass(input)
        self.probs = defaultdict(Counter)

  def count_ngrams_inclass(self, input):
        tokens = tokenize(input)

        counts = defaultdict(Counter)
        for tok_line in tokens:
          tokens = [UNK] * (self.n-1) + tok_line + [EOS]
          for i in range(self.n-1, len(tokens)):
            keys = tuple(tokens[i-self.n+1:i])
            counts[keys][tokens[i]] += 1

        return counts

  def get_possible_next_tokens(self, prefix):
          """
          :param prefix: string with space - separated prefix tokens
          :returns: a dictionary {token : it's probability} for all tokens with positive probabilities
          """
          tokenizer = WordPunctTokenizer()
          prefix = tokenizer.tokenize(prefix.lower())

          prefix = prefix[max(0, len(prefix) - self.n + 1):]
          prefix = [ UNK ] * (self.n - 1 - len(prefix)) + prefix
          probs = self.ngrams[tuple(prefix)]
          all_probs = sum(probs.values())
          probs = {key: probs[key]/all_probs for key in probs}
          return probs

  def get_next_token_prob(self, prefix, next_token):
          """
          :param prefix: string with space-separated prefix tokens
          :param next_token: the next token to predict probability for
          :returns: P(next_token|prefix) a single number, 0 <= P <= 1
          """
          return self.get_possible_next_tokens(prefix).get(next_token, 0)

  def get_next_token(self, prefix, temperature=1.0):
          """
          return next token after prefix;
          :param temperature: samples proportionally to lm probabilities ^ (1 / temperature)
              if temperature == 0, always takes most likely token. Break ties arbitrarily.
          """
          prefix_probabilities = self.get_possible_next_tokens(prefix)
          if temperature == 0.0:
            next_token = max(prefix_probabilities, key=prefix_probabilities.get)
            return next_token

          softened_probabilities = {word: prob ** (1 / temperature) for word, prob in prefix_probabilities.items()}
          normalization_term = sum(softened_probabilities.values())
          normalized_probabilities = {word: prob / normalization_term for word, prob in softened_probabilities.items()}
          # next_token = np.random.choice(list(normalized_probabilities.keys()), p=list(normalized_probabilities.values()))

          # return next_token

  def generate(self, prefix):
          for i in range(100):
              prefix += ' ' + self.get_next_token(lm, prefix, 0.7)
              if prefix.endswith(EOS) or len(self.get_possible_next_tokens(prefix)) == 0:
                  break
          text = prefix
          return text[:len(text)-5]

# %%
model = NGramModel(lines, 3)

# %%
x = model.get_next_token("end of the", 1)

# %%
x = generate("end of the")
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-241-9fd626c7d5b6> in <cell line: 1>()
# ----> 1 x = generate("end of the")
#       2 print(x)
#
# <ipython-input-218-4a210e9dc5e0> in generate(prefix)
#       3 def generate(prefix):
#       4   for i in range(100):
# ----> 5       prefix += ' ' + get_next_token(lm, prefix, 0.7)
#       6       if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
#       7           break
#
# <ipython-input-233-29152344745f> in get_next_token(lm, prefix, temperature)
#      12     normalization_term = sum(softened_probabilities.values())
#      13     normalized_probabilities = {word: prob / normalization_term for word, prob in softened_probabilities.items()}
# ---> 14     next_token = np.random.choice(list(normalized_probabilities.keys()), p=list(normalized_probabilities.values()))
#      15
#      16     return next_token
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: 'a' cannot be empty unless no samples are taken
